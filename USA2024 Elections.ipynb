# %% [markdown]
# # USA2024 Elections - Dataset Manipulation 🤹🏼

# %% [markdown]
# ## Goal: Allan Lichtman Theory + 1976-2020_public_dataset

# %% [markdown]
# ***

# %% [markdown]
# - 1976-2020 Public Dataset overview

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("1976-2020-president.csv")
df
# Out:
#       year    state state_po  state_fips  state_cen  state_ic        office  \
# 0     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 1     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 2     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 3     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 4     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# ...    ...      ...      ...         ...        ...       ...           ...
# 4282  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4283  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4284  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4285  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4286  2020  WYOMING       WY          56         83        68  US PRESIDENT
#
#                     candidate              party_detailed writein  \
# 0               CARTER, JIMMY                    DEMOCRAT   False
# 1                FORD, GERALD                  REPUBLICAN   False
# 2              MADDOX, LESTER  AMERICAN INDEPENDENT PARTY   False
# 3     BUBAR, BENJAMIN ""BEN""                 PROHIBITION   False
# 4                   HALL, GUS         COMMUNIST PARTY USE   False
# ...                       ...                         ...     ...
# 4282            JORGENSEN, JO                 LIBERTARIAN   False
# 4283            PIERCE, BROCK                 INDEPENDENT   False
# 4284                      NaN                         NaN    True
# 4285                OVERVOTES                         NaN   False
# 4286               UNDERVOTES                         NaN   False
#
#       candidatevotes  totalvotes   version  notes party_simplified
# 0             659170     1182850  20210113    NaN         DEMOCRAT
# 1             504070     1182850  20210113    NaN       REPUBLICAN
# 2               9198     1182850  20210113    NaN            OTHER
# 3               6669     1182850  20210113    NaN            OTHER
# 4               1954     1182850  20210113    NaN            OTHER
# ...              ...         ...       ...    ...              ...
# 4282            5768      278503  20210113    NaN      LIBERTARIAN
# 4283            2208      278503  20210113    NaN            OTHER
# 4284            1739      278503  20210113    NaN            OTHER
# 4285             279      278503  20210113    NaN            OTHER
# 4286            1459      278503  20210113    NaN            OTHER
#
# [4287 rows x 15 columns]

# %%
df_treatment = df.drop(["notes","party_detailed","state_po","state_fips","state_cen","state_ic","office"], axis=1)
df_treatment
# Out:
#       year    state                candidate writein  candidatevotes  \
# 0     1976  ALABAMA            CARTER, JIMMY   False          659170
# 1     1976  ALABAMA             FORD, GERALD   False          504070
# 2     1976  ALABAMA           MADDOX, LESTER   False            9198
# 3     1976  ALABAMA  BUBAR, BENJAMIN ""BEN""   False            6669
# 4     1976  ALABAMA                HALL, GUS   False            1954
# ...    ...      ...                      ...     ...             ...
# 4282  2020  WYOMING            JORGENSEN, JO   False            5768
# 4283  2020  WYOMING            PIERCE, BROCK   False            2208
# 4284  2020  WYOMING                      NaN    True            1739
# 4285  2020  WYOMING                OVERVOTES   False             279
# 4286  2020  WYOMING               UNDERVOTES   False            1459
#
#       totalvotes   version party_simplified
# 0        1182850  20210113         DEMOCRAT
# 1        1182850  20210113       REPUBLICAN
# 2        1182850  20210113            OTHER
# 3        1182850  20210113            OTHER
# 4        1182850  20210113            OTHER
# ...          ...       ...              ...
# 4282      278503  20210113      LIBERTARIAN
# 4283      278503  20210113            OTHER
# 4284      278503  20210113            OTHER
# 4285      278503  20210113            OTHER
# 4286      278503  20210113            OTHER
#
# [4287 rows x 8 columns]

# %% [markdown]
# ***

# %%
df_treatment.isnull().sum()#check for missing values
# Out:
# year                  0
# state                 0
# candidate           287
# writein               3
# candidatevotes        0
# totalvotes            0
# version               0
# party_simplified      0
# dtype: int64

# %%
df_treatment2 = df_treatment.dropna()
df_treatment2 #drop'em
# Out:
#       year    state                candidate writein  candidatevotes  \
# 0     1976  ALABAMA            CARTER, JIMMY   False          659170
# 1     1976  ALABAMA             FORD, GERALD   False          504070
# 2     1976  ALABAMA           MADDOX, LESTER   False            9198
# 3     1976  ALABAMA  BUBAR, BENJAMIN ""BEN""   False            6669
# 4     1976  ALABAMA                HALL, GUS   False            1954
# ...    ...      ...                      ...     ...             ...
# 4281  2020  WYOMING         TRUMP, DONALD J.   False          193559
# 4282  2020  WYOMING            JORGENSEN, JO   False            5768
# 4283  2020  WYOMING            PIERCE, BROCK   False            2208
# 4285  2020  WYOMING                OVERVOTES   False             279
# 4286  2020  WYOMING               UNDERVOTES   False            1459
#
#       totalvotes   version party_simplified
# 0        1182850  20210113         DEMOCRAT
# 1        1182850  20210113       REPUBLICAN
# 2        1182850  20210113            OTHER
# 3        1182850  20210113            OTHER
# 4        1182850  20210113            OTHER
# ...          ...       ...              ...
# 4281      278503  20210113       REPUBLICAN
# 4282      278503  20210113      LIBERTARIAN
# 4283      278503  20210113            OTHER
# 4285      278503  20210113            OTHER
# 4286      278503  20210113            OTHER
#
# [3998 rows x 8 columns]

# %%
unique_values = df_treatment3["version"].unique()
unique_values
# Out:
# array([ 1182850,   123574,   742719,   767535,  7803770,  1081440,
#         1386355,   235642,   168830,  3150631,  1463152,   291301,
#          340932,  4721282,  2220362,  1279303,   957845,  1167142,
#         1277383,   482968,  1432273,  2547558,  3651590,  1949931,
#          768390,  1953600,   328734,   606749,   201876,   339627,
#         3014472,   416590,  6668262,  1677906,   297308,  4110456,
#         1092251,  1029876,  4620787,   410584,   802583,   300678,
#         1476346,  4071884,   541218,   183902,  1697094,  1555534,
#          750590,  2101336,   156343,  1341929,   158445,   873945,
#          837582,  8582938,  1184450,  1406285,   235668,   173889,
#         3686927,  1596805,   303287,   437431,  4749721,  2242033,
#         1317661,   979795,  1295627,  1548591,   523011,  1540496,
#         2524090,  3909725,  2051916,   891750,  2099824,   363952,
#          639533,   243692,   383990,  2975684,   456237,  6201959,
#         1855833,   301116,  4283603,  1149708,  1181516,  4561501,
#          415967,   888258,   327703,  1617616,  4541636,   604152,
#          213299,  1866032,  1742394,   737715,  2273221,   176713,
#         1441713,   207605,  1025897,   884406,  9505041,  1295380,
#         1466900,   254572,   211288,  4180051,  1776103,   335846,
#          411144,  4819088,  2233069,  1319805,  1021991,  1369345,
#         1706822,   553144,  1675873,  2559383,  3801658,  2084449,
#          941104,  2122771,   384377,   652090,   282717,   388904,
#         3217862,   514370,  6806810,  2175361,   308971,  4563235,
#         1255676,  1226527,  4844903,   410489,   968529,   317867,
#         1711993,  5397571,   629656,   234561,  2146635,  1874910,
#          735742,  2211689,   188968,  1378476,   200116,  1171873,
#          827738,  9887065,  1372394,  1443394,   249891,   192877,
#         4302313,  1809672,   354461,   408968,  4559120,  2168621,
#         1225614,   993044,  1322517,  1628202,   555035,  1714358,
#         2632801,  3669163,  2096790,   931527,  2093228,   365674,
#          661465,   343133,   450525,  3099553,   521387,  6485683,
#         2134370,   297261,  4393585,  1171036,  1201694,  4536251,
#          404622,   986009,   312991,  1636250,  5427410,   647008,
#          243328,  2191609,  1865253,   653311,  2191608,   176551,
#         1688060,   258506,  1486975,   950653, 11131721,  1569180,
#         1616156,   289620,   227572,  5313392,  2321133,   372842,
#          482114,  5050157,  2305871,  1354607,  1157236,  1492900,
#         1790017,   679499,  1984580,  2773664,  4274673,  2347948,
#          981793,  2391270,   410583,   737546,   506318,   537215,
#         3343594,   569986,  7079432,  2611850,   308133,  4939967,
#         1390359,  1462643,  4959810,   453365,  1228912,   336254,
#         1982638,  6154018,   743998,   289701,  2559129,  2287565,
#          683677,  2531064,   199884,  1534349,   241620,  1404405,
#          884262, 10019469,  1510702,  1392614,   270810,   185726,
#         5303154,  2298899,   360120,   491711,  4311391,  2135431,
#         1234075,  1074300,  1388708,  1783959,   605897,  1780870,
#         2556459,  3848844,  2192492,   893857,  2158065,   407083,
#          677415,   464279,   496597,  3075860,   556074,  6439129,
#         2515807,   266411,  4534434,  1206713,  1377760,  4501307,
#          390247,  1150182,   323826,  1894105,  5611644,   665629,
#          258449,  2416642,  2253837,   636459,  2196169,   211571,
#         1666272,   285560,  1532016,   921781, 10965822,  1741368,
#         1459525,   327529,   201894,  5963110,  2583208,   367951,
#          501615,  4742108,  2199302,  1353022,  1072216,  1544106,
#         1765656,   651817,  2025212,  2733964,  4232501,  2438685,
#          994184,  2359892,   410986,   697019,   609426,   569081,
#         3187226,   598605,  6960215,  2914990,   288256,  4701998,
#         1234229,  1533950,  4912185,   409112,  1383902,   316269,
#         2076181,  6407637,   770754,   294308,  2739447,  2487433,
#          648124,  2598607,   213726,  1883415,   312598,  2012585,
#         1054945, 12421353,  2129630,  1578769,   375190,   227586,
#         7609810,  3301875,   429013,   598376,  5274322,  2468002,
#         1506908,  1187756,  1795882,  1943106,   740752,  2384238,
#         2927455,  4839252,  2828387,  1139824,  2731364,   450434,
#          778186,   829587,   678287,  3611691,   756304,  7448266,
#         3501007,   312833,  5627903,  1463758,  1836782,  5769590,
#          437134,  1617700,   388215,  2437319,  7410749,   927844,
#          312309,  3195415,  2859084,   755792,  2997007,   243861,
#         2099819,   326197,  2293475,  1086617, 13561900,  2401361,
#         1646792,   412412,   265853,  8390744,  3924486,   456064,
#          655122,  5522371,  2751054,  1537123,  1235872,  1826620,
#         1960761,   731163,  2631596,  3102995,  5001596,  2910369,
#         1289865,  2925205,   490109,   801281,   967848,   710970,
#         3868237,   830158,  7722019,  4310851,   316621,  5708350,
#         1462661,  1827864,  6013272,   471766,  1920969,   381975,
#         2599749,  8077795,   952370,   325046,  3723260,  3036878,
#          713451,  2983417,   254904,  2074338,   300495,  2299254,
#         1069468, 13038547,  2569516,  1558204,   413890,   293764,
#         8474179,  3897839,   437159,   652274,  5242014,  2624534,
#         1582180,  1159971,  1797212,  1994065,   724758,  2707327,
#         3184196,  4730961,  2936561,  1285584,  2757323,   484048,
#          794379,  1014918,   710972,  3638499,   783758,  7116784,
#         4505372,   322932,  5580822,  1334872,  1789270,  5742040,
#          446049,  1964118,   363815,  2458577,  7993851,  1017440,
#          299290,  3854489,  3125516,   670438,  3071434,   250701,
#         2123372,   318608,  2573165,  1130635, 14181595,  2780220,
#         1644920,   441590,   312575,  9420039,  4114732,   437664,
#          690255,  5536424,  2734958,  1565580,  1184402,  1924149,
#         2029032,   771892,  2781446,  3378821,  4799284,  2944782,
#         1209357,  2808605,   494526,   844227,  1125385,   744296,
#         3874046,   798319,  7802084,  4741564,   344360,  5496487,
#         1452992,  2001336,  6115402,   464144,  2103027,   370093,
#         2508027,  8969226,  1131317,   320467,  3982752,  3317019,
#          713051,  2976150,   258788,  2323282,   359530,  3387326,
#         1219069, 17500881,  3279980,  1823857,   504346,   344356,
#        11067456,  4999960,   579784,   868014,  6033743,  3033118,
#         1700130,  1372303,  2136768,  2148062,   828305,  3037030,
#         3658005,  5539302,  3277171,  1313759,  3025962,   603674,
#          956383,  1405376,   806182,  4549353,   923965,  8661735,
#         5524802,   361819,  5922202,  1560699,  2374321,  6915283,
#          516990,  2514096,   422609,  3053851, 11315056,  1488289,
#          370968,  4460524,  4087631,   794652,  3298041,   278503])

# %%
df_treatment3 = df_treatment2.drop(["writein", "version"], axis=1)
df_treatment3
# Out:
#       year    state                candidate  candidatevotes  totalvotes  \
# 0     1976  ALABAMA            CARTER, JIMMY          659170     1182850
# 1     1976  ALABAMA             FORD, GERALD          504070     1182850
# 2     1976  ALABAMA           MADDOX, LESTER            9198     1182850
# 3     1976  ALABAMA  BUBAR, BENJAMIN ""BEN""            6669     1182850
# 4     1976  ALABAMA                HALL, GUS            1954     1182850
# ...    ...      ...                      ...             ...         ...
# 4281  2020  WYOMING         TRUMP, DONALD J.          193559      278503
# 4282  2020  WYOMING            JORGENSEN, JO            5768      278503
# 4283  2020  WYOMING            PIERCE, BROCK            2208      278503
# 4285  2020  WYOMING                OVERVOTES             279      278503
# 4286  2020  WYOMING               UNDERVOTES            1459      278503
#
#      party_simplified
# 0            DEMOCRAT
# 1          REPUBLICAN
# 2               OTHER
# 3               OTHER
# 4               OTHER
# ...               ...
# 4281       REPUBLICAN
# 4282      LIBERTARIAN
# 4283            OTHER
# 4285            OTHER
# 4286            OTHER
#
# [3998 rows x 6 columns]

# %%
unique_partys = df_treatment3["party_simplified"].unique()
unique_partys
# Out:
# array(['DEMOCRAT', 'REPUBLICAN', 'OTHER', 'LIBERTARIAN'], dtype=object)

# %%
df_final = df_treatment3.drop(df_treatment3[df_treatment3["party_simplified"] == "OTHER"].index)
df_final_1 = df_final.drop(df_final[df_final["party_simplified"] == "LIBERTARIAN"].index)
df_final_1
# Out:
#       year          state            candidate  candidatevotes  totalvotes  \
# 0     1976        ALABAMA        CARTER, JIMMY          659170     1182850
# 1     1976        ALABAMA         FORD, GERALD          504070     1182850
# 7     1976         ALASKA         FORD, GERALD           71555      123574
# 8     1976         ALASKA        CARTER, JIMMY           44058      123574
# 11    1976        ARIZONA         FORD, GERALD          418642      742719
# ...    ...            ...                  ...             ...         ...
# 4264  2020  WEST VIRGINIA     TRUMP, DONALD J.          545382      794652
# 4267  2020      WISCONSIN  BIDEN, JOSEPH R. JR         1630866     3298041
# 4268  2020      WISCONSIN     TRUMP, DONALD J.         1610184     3298041
# 4280  2020        WYOMING  BIDEN, JOSEPH R. JR           73491      278503
# 4281  2020        WYOMING     TRUMP, DONALD J.          193559      278503
#
#      party_simplified
# 0            DEMOCRAT
# 1          REPUBLICAN
# 7          REPUBLICAN
# 8            DEMOCRAT
# 11         REPUBLICAN
# ...               ...
# 4264       REPUBLICAN
# 4267         DEMOCRAT
# 4268       REPUBLICAN
# 4280         DEMOCRAT
# 4281       REPUBLICAN
#
# [1227 rows x 6 columns]

# %%
year_1976 = df_final_1[df_final_1['year'] == 1976] #Isolation just to check for some data insights
year_1976

# %%
unique_1976 = year_1976["state"].unique()
unique_1976

# %%
len(unique_1976) #Okay lets proceed with what we were doing

# %%
df_final_1
# Out:
#       year          state            candidate  candidatevotes  totalvotes  \
# 0     1976        ALABAMA        CARTER, JIMMY          659170     1182850
# 1     1976        ALABAMA         FORD, GERALD          504070     1182850
# 7     1976         ALASKA         FORD, GERALD           71555      123574
# 8     1976         ALASKA        CARTER, JIMMY           44058      123574
# 11    1976        ARIZONA         FORD, GERALD          418642      742719
# ...    ...            ...                  ...             ...         ...
# 4264  2020  WEST VIRGINIA     TRUMP, DONALD J.          545382      794652
# 4267  2020      WISCONSIN  BIDEN, JOSEPH R. JR         1630866     3298041
# 4268  2020      WISCONSIN     TRUMP, DONALD J.         1610184     3298041
# 4280  2020        WYOMING  BIDEN, JOSEPH R. JR           73491      278503
# 4281  2020        WYOMING     TRUMP, DONALD J.          193559      278503
#
#      party_simplified
# 0            DEMOCRAT
# 1          REPUBLICAN
# 7          REPUBLICAN
# 8            DEMOCRAT
# 11         REPUBLICAN
# ...               ...
# 4264       REPUBLICAN
# 4267         DEMOCRAT
# 4268       REPUBLICAN
# 4280         DEMOCRAT
# 4281       REPUBLICAN
#
# [1227 rows x 6 columns]

# %%
df_final_1['vote_percentage'] = (df_final_1['candidatevotes'] / df_final_1['totalvotes']) * 100
df_final_1
# Out:
#       year          state            candidate  candidatevotes  totalvotes  \
# 0     1976        ALABAMA        CARTER, JIMMY          659170     1182850
# 1     1976        ALABAMA         FORD, GERALD          504070     1182850
# 7     1976         ALASKA         FORD, GERALD           71555      123574
# 8     1976         ALASKA        CARTER, JIMMY           44058      123574
# 11    1976        ARIZONA         FORD, GERALD          418642      742719
# ...    ...            ...                  ...             ...         ...
# 4264  2020  WEST VIRGINIA     TRUMP, DONALD J.          545382      794652
# 4267  2020      WISCONSIN  BIDEN, JOSEPH R. JR         1630866     3298041
# 4268  2020      WISCONSIN     TRUMP, DONALD J.         1610184     3298041
# 4280  2020        WYOMING  BIDEN, JOSEPH R. JR           73491      278503
# 4281  2020        WYOMING     TRUMP, DONALD J.          193559      278503
#
#      party_simplified  vote_percentage
# 0            DEMOCRAT        55.727269
# 1          REPUBLICAN        42.614871
# 7          REPUBLICAN        57.904575
# 8            DEMOCRAT        35.653131
# 11         REPUBLICAN        56.366136
# ...               ...              ...
# 4264       REPUBLICAN        68.631552
# 4267         DEMOCRAT        49.449537
# 4268       REPUBLICAN        48.822437
# 4280         DEMOCRAT        26.387867
# 4281       REPUBLICAN        69.499790
#
# [1227 rows x 7 columns]

# %% [markdown]
# ***

# %% [markdown]
# - Allan Lichtman Keys thanks to BeautifulSoup 🍲  (Scrape \& Creation of the Lichtman dataframe)

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://en.wikipedia.org/wiki/The_Keys_to_the_White_House"
r = requests.get(url)
soup = BeautifulSoup(r.text ,"html.parser")

# %%
tables = pd.read_html(str(soup))
tables
# Out:
# [     #                               Name  \
#  0    1                      Party mandate
#  1    2                 No primary contest
#  2    3      Incumbent seeking re-election
#  3    4                     No third party
#  4    5          Strong short-term economy
#  5    6           Strong long-term economy
#  6    7                Major policy change
#  7    8                   No social unrest
#  8    9                         No scandal
#  9   10     No foreign or military failure
#  10  11  Major foreign or military success
#  11  12              Charismatic incumbent
#  12  13           Uncharismatic challenger
#
#                                        Description[18]
#  0   After the midterm elections, the incumbent par...
#  1   There is no serious contest for the incumbent ...
#  2   The incumbent party candidate is the sitting p...
#  3   There is no significant third party or indepen...
#  4   The economy is not in recession during the ele...
#  5   Real per capita economic growth during the ter...
#  6   The incumbent administration effects major cha...
#  7   There is no sustained social unrest during the...
#  8   The incumbent administration is untainted by m...
#  9   The incumbent administration suffers no major ...
#  10  The incumbent administration achieves a major ...
#  11  The incumbent party candidate is charismatic o...
#  12  The challenging party candidate is not charism...  ,
#     Election              Incumbent party nominee  \
#  0      1860      Stephen A. Douglas (Democratic)
#  1      1864   Abraham Lincoln (Union/Republican)
#  2   1868[i]        Ulysses S. Grant (Republican)
#  3   1868[n]         Horatio Seymour (Democratic)
#  4      1872        Ulysses S. Grant (Republican)
#  5      1876     Rutherford B. Hayes (Republican)
#  6      1880       James A. Garfield (Republican)
#  7      1884         James G. Blaine (Republican)
#  8      1888        Grover Cleveland (Democratic)
#  9      1892       Benjamin Harrison (Republican)
#  10     1896  William Jennings Bryan (Democratic)
#  11     1900        William McKinley (Republican)
#  12     1904      Theodore Roosevelt (Republican)
#  13     1908     William Howard Taft (Republican)
#  14     1912     William Howard Taft (Republican)
#  15     1916          Woodrow Wilson (Democratic)
#  16     1920            James M. Cox (Democratic)
#  17     1924         Calvin Coolidge (Republican)
#  18     1928          Herbert Hoover (Republican)
#  19     1932          Herbert Hoover (Republican)
#  20     1936   Franklin D. Roosevelt (Democratic)
#  21     1940   Franklin D. Roosevelt (Democratic)
#  22     1944   Franklin D. Roosevelt (Democratic)
#  23     1948         Harry S. Truman (Democratic)
#  24     1952      Adlai Stevenson II (Democratic)
#  25     1956    Dwight D. Eisenhower (Republican)
#  26     1960           Richard Nixon (Republican)
#  27     1964       Lyndon B. Johnson (Democratic)
#  28     1968         Hubert Humphrey (Democratic)
#  29     1972           Richard Nixon (Republican)
#  30     1976             Gerald Ford (Republican)
#  31     1980            Jimmy Carter (Democratic)
#
#                 Challenger party nominee Party mandate No primary contest  \
#  0          Abraham Lincoln (Republican)          True           False[a]
#  1         George McClellan (Democratic)       True[e]               True
#  2          Horatio Seymour (Democratic)          True               True
#  3         Ulysses S. Grant (Republican)         False           False[o]
#  4     Horace Greeley (Democrat/Liberal)         False               True
#  5         Samuel J. Tilden (Democratic)         False           False[r]
#  6   Winfield Scott Hancock (Democratic)          True           False[v]
#  7         Grover Cleveland (Democratic)         False           False[x]
#  8        Benjamin Harrison (Republican)         False               True
#  9         Grover Cleveland (Democratic)         False          False[ab]
#  10        William McKinley (Republican)         False          False[af]
#  11  William Jennings Bryan (Democratic)         False               True
#  12     Alton Brooks Parker (Democratic)          True               True
#  13  William Jennings Bryan (Democratic)          True               True
#  14          Woodrow Wilson (Democratic)         False          False[aq]
#  15    Charles Evans Hughes (Republican)         False               True
#  16       Warren G. Harding (Republican)         False          False[av]
#  17           John W. Davis (Democratic)         False               True
#  18                Al Smith (Democratic)          True               True
#  19   Franklin D. Roosevelt (Democratic)         False               True
#  20              Alf Landon (Republican)          True               True
#  21         Wendell Willkie (Republican)         False               True
#  22            Thomas Dewey (Republican)         False               True
#  23            Thomas Dewey (Republican)         False           True[bn]
#  24    Dwight D. Eisenhower (Republican)          True          False[bs]
#  25      Adlai Stevenson II (Democratic)          True               True
#  26         John F. Kennedy (Democratic)         False               True
#  27         Barry Goldwater (Republican)         False               True
#  28           Richard Nixon (Republican)         False          False[cd]
#  29         George McGovern (Democratic)         False               True
#  30            Jimmy Carter (Democratic)         False          False[cl]
#  31           Ronald Reagan (Republican)         False          False[cp]
#
#      Incumbent seeking re-election No third party Strong short-term economy  \
#  0                           False       False[b]                      True
#  1                            True           True                      True
#  2                           False           True                      True
#  3                           False           True                      True
#  4                            True           True                      True
#  5                           False           True                  False[s]
#  6                           False           True                      True
#  7                           False           True                  False[y]
#  8                            True           True                      True
#  9                            True      False[ac]                      True
#  10                          False           True                 False[ag]
#  11                           True           True                      True
#  12                           True           True                      True
#  13                          False           True                  True[am]
#  14                           True      False[ar]                      True
#  15                           True           True                      True
#  16                          False           True                 False[aw]
#  17                           True      False[bb]                      True
#  18                          False           True                      True
#  19                           True           True                 False[bg]
#  20                           True           True                      True
#  21                           True           True                      True
#  22                           True           True                      True
#  23                           True      False[bo]                      True
#  24                          False           True                      True
#  25                           True           True                      True
#  26                          False           True                 False[bx]
#  27                           True           True                      True
#  28                          False      False[ce]                      True
#  29                           True           True                  True[ci]
#  30                           True           True                  True[cm]
#  31                           True      False[cq]                 False[cr]
#
#      Strong long-term economy Major policy change No social unrest No scandal  \
#  0                       True               False         False[c]       True
#  1                      False             True[f]         False[g]       True
#  2                       True             True[j]         False[k]    True[l]
#  3                       True             True[j]         False[k]    True[l]
#  4                       True               False         False[p]       True
#  5                      False               False             True   False[t]
#  6                       True             True[w]             True       True
#  7                      False               False             True       True
#  8                       True               False         False[z]       True
#  9                       True            True[ad]        False[ae]       True
#  10                     False               False        False[ah]       True
#  11                      True            True[ai]             True       True
#  12                      True            True[ak]             True       True
#  13                     False            True[an]             True       True
#  14                      True               False             True       True
#  15                     False            True[at]             True       True
#  16                     False            True[ax]        False[ay]       True
#  17                      True            True[bc]             True  False[bd]
#  18                      True               False             True       True
#  19                     False               False        False[bh]       True
#  20                      True            True[bi]             True       True
#  21                      True            True[bj]             True       True
#  22                      True            True[bk]             True       True
#  23                     False            True[bp]             True       True
#  24                     False               False             True  False[bt]
#  25                      True               False             True       True
#  26                     False               False             True       True
#  27                      True            True[ca]             True       True
#  28                      True            True[cf]        False[cg]       True
#  29                     False               False             True   True[cj]
#  30                     False               False             True  False[cn]
#  31                      True               False             True       True
#
#     No foreign or military failure Major foreign or military success  \
#  0                            True                             False
#  1                            True                           True[h]
#  2                            True                           True[m]
#  3                            True                           True[m]
#  4                            True                           True[q]
#  5                            True                             False
#  6                            True                             False
#  7                            True                             False
#  8                            True                             False
#  9                            True                             False
#  10                           True                             False
#  11                           True                          True[aj]
#  12                           True                          True[al]
#  13                           True                          True[ao]
#  14                           True                             False
#  15                           True                          True[au]
#  16                      False[az]                          True[ba]
#  17                           True                          True[be]
#  18                           True                          True[bf]
#  19                           True                             False
#  20                           True                             False
#  21                           True                             False
#  22                      False[bl]                          True[bm]
#  23                      False[bq]                          True[br]
#  24                      False[bu]                          True[bv]
#  25                           True                          True[bw]
#  26                      False[by]                             False
#  27                      False[cb]                          True[cc]
#  28                      False[ch]                             False
#  29                           True                          True[ck]
#  30                      False[co]                             False
#  31                      False[cs]                          True[ct]
#
#      Charismatic incumbent Uncharismatic challenger  False keys  \
#  0                   False                  True[d]           7
#  1                   False                     True           3
#  2                    True                     True           2
#  3                   False                    False           6
#  4                    True                     True           3
#  5                   False                     True           9
#  6                   False                     True           4
#  7                    True                     True           7
#  8                   False                     True           5
#  9                   False                     True           6
#  10                   True                     True           8
#  11                  False                    False           3
#  12                   True                     True           0
#  13                  False                 True[ap]           3
#  14                  False                     True           6
#  15                  False                     True           3
#  16                  False                     True           8
#  17                  False                     True           4
#  18                  False                     True           3
#  19                  False                    False           8
#  20                   True                     True           1
#  21                   True                     True           2
#  22                   True                     True           2
#  23                  False                     True           5
#  24                  False                    False           8
#  25                   True                     True           1
#  26                  False                    False           9
#  27                  False                     True           3
#  28                  False                     True           8
#  29                  False                     True           4
#  30                  False                     True           8
#  31                  False                    False           8
#
#            Presumed winner          Actual winner
#  0         Abraham Lincoln        Abraham Lincoln
#  1         Abraham Lincoln        Abraham Lincoln
#  2        Ulysses S. Grant       Ulysses S. Grant
#  3        Ulysses S. Grant       Ulysses S. Grant
#  4        Ulysses S. Grant       Ulysses S. Grant
#  5     Samuel J. Tilden[u]    Rutherford B. Hayes
#  6       James A. Garfield      James A. Garfield
#  7        Grover Cleveland       Grover Cleveland
#  8    Grover Cleveland[aa]      Benjamin Harrison
#  9        Grover Cleveland       Grover Cleveland
#  10       William McKinley       William McKinley
#  11       William McKinley       William McKinley
#  12     Theodore Roosevelt     Theodore Roosevelt
#  13    William Howard Taft    William Howard Taft
#  14     Woodrow Wilson[as]     Woodrow Wilson[as]
#  15         Woodrow Wilson         Woodrow Wilson
#  16      Warren G. Harding      Warren G. Harding
#  17        Calvin Coolidge        Calvin Coolidge
#  18         Herbert Hoover         Herbert Hoover
#  19  Franklin D. Roosevelt  Franklin D. Roosevelt
#  20  Franklin D. Roosevelt  Franklin D. Roosevelt
#  21  Franklin D. Roosevelt  Franklin D. Roosevelt
#  22  Franklin D. Roosevelt  Franklin D. Roosevelt
#  23        Harry S. Truman        Harry S. Truman
#  24   Dwight D. Eisenhower   Dwight D. Eisenhower
#  25   Dwight D. Eisenhower   Dwight D. Eisenhower
#  26    John F. Kennedy[bz]    John F. Kennedy[bz]
#  27      Lyndon B. Johnson      Lyndon B. Johnson
#  28          Richard Nixon          Richard Nixon
#  29          Richard Nixon          Richard Nixon
#  30           Jimmy Carter           Jimmy Carter
#  31          Ronald Reagan          Ronald Reagan  ,
#      Election         Incumbent party nominee      Challenger party nominee  \
#  0       1984      Ronald Reagan (Republican)   Walter Mondale (Democratic)
#  1       1988  George H. W. Bush (Republican)  Michael Dukakis (Democratic)
#  2       1992  George H. W. Bush (Republican)     Bill Clinton (Democratic)
#  3       1996       Bill Clinton (Democratic)         Bob Dole (Republican)
#  4       2000            Al Gore (Democratic)   George W. Bush (Republican)
#  5       2004     George W. Bush (Republican)       John Kerry (Democratic)
#  6       2008        John McCain (Republican)     Barack Obama (Democratic)
#  7       2012       Barack Obama (Democratic)      Mitt Romney (Republican)
#  8       2016    Hillary Clinton (Democratic)     Donald Trump (Republican)
#  9       2020       Donald Trump (Republican)        Joe Biden (Democratic)
#  10      2024      Kamala Harris (Democratic)     Donald Trump (Republican)
#
#      Party mandate No primary contest  Incumbent seeking re-election  \
#  0            True               True                           True
#  1            True           True[cv]                          False
#  2           False               True                           True
#  3           False               True                           True
#  4            True               True                          False
#  5            True               True                           True
#  6           False           True[dg]                          False
#  7           False               True                           True
#  8           False          False[dm]                          False
#  9           False               True                           True
#  10          False               True                          False
#
#     No third party Strong short-term economy  Strong long-term economy  \
#  0            True                      True                     False
#  1            True                      True                      True
#  2       False[cy]             False[cz][50]                     False
#  3       False[db]                      True                      True
#  4            True                      True                      True
#  5            True                      True                     False
#  6            True                 False[dh]                     False
#  7            True                      True                     False
#  8        True[dn]                      True                      True
#  9            True                 False[dq]                     False
#  10           True                      True                      True
#
#     Major policy change No social unrest No scandal  \
#  0             True[cu]             True       True
#  1                False             True   True[cw]
#  2                False             True       True
#  3                False             True       True
#  4                False             True  False[dc]
#  5                False             True       True
#  6                False             True       True
#  7             True[dj]             True       True
#  8                False             True       True
#  9             True[dr]        False[ds]  False[dt]
#  10            True[du]             True       True
#
#     No foreign or military failure Major foreign or military success  \
#  0                            True                             False
#  1                            True                          True[cx]
#  2                            True                          True[da]
#  3                            True                             False
#  4                            True                             False
#  5                       False[de]                          True[df]
#  6                       False[di]                             False
#  7                            True                          True[dk]
#  8                            True                             False
#  9                            True                             False
#  10                  False[dv][54]                      True[dw][55]
#
#     Charismatic incumbent  Uncharismatic challenger False keys  \
#  0                   True                      True          2
#  1                  False                      True          3
#  2                  False                      True          6
#  3                  False                      True          5
#  4                  False                      True          5
#  5                  False                      True          4
#  6                  False                     False          9
#  7              False[dl]                      True          3
#  8                  False                      True      6[do]
#  9                  False                      True          7
#  10                 False                      True          4
#
#             Predicted winner            Actual winner
#  0             Ronald Reagan            Ronald Reagan
#  1         George H. W. Bush        George H. W. Bush
#  2              Bill Clinton             Bill Clinton
#  3              Bill Clinton             Bill Clinton
#  4               Al Gore[dd]           George W. Bush
#  5            George W. Bush           George W. Bush
#  6              Barack Obama             Barack Obama
#  7              Barack Obama             Barack Obama
#  8   Donald Trump[dp][6][52]  Donald Trump[dp][6][52]
#  9             Joe Biden[53]            Joe Biden[53]
#  10        Kamala Harris[56]                      TBD  ]

# %%
for index, table in enumerate(tables): #first lets select all the tables by indexes just to check 
    print(f"Table{index}:")
    print(table.head())
# Out:
# Table0:
#    #                           Name  \
# 0  1                  Party mandate
# 1  2             No primary contest
# 2  3  Incumbent seeking re-election
# 3  4                 No third party
# 4  5      Strong short-term economy
#
#                                      Description[18]
# 0  After the midterm elections, the incumbent par...
# 1  There is no serious contest for the incumbent ...
# 2  The incumbent party candidate is the sitting p...
# 3  There is no significant third party or indepen...
# 4  The economy is not in recession during the ele...
# Table1:
#   Election             Incumbent party nominee  \
# 0     1860     Stephen A. Douglas (Democratic)
# 1     1864  Abraham Lincoln (Union/Republican)
# 2  1868[i]       Ulysses S. Grant (Republican)
# 3  1868[n]        Horatio Seymour (Democratic)
# 4     1872       Ulysses S. Grant (Republican)
#
#             Challenger party nominee Party mandate No primary contest  \
# 0       Abraham Lincoln (Republican)          True           False[a]
# 1      George McClellan (Democratic)       True[e]               True
# 2       Horatio Seymour (Democratic)          True               True
# 3      Ulysses S. Grant (Republican)         False           False[o]
# 4  Horace Greeley (Democrat/Liberal)         False               True
#
#    Incumbent seeking re-election No third party Strong short-term economy  \
# 0                          False       False[b]                      True
# 1                           True           True                      True
# 2                          False           True                      True
# 3                          False           True                      True
# 4                           True           True                      True
#
#    Strong long-term economy Major policy change No social unrest No scandal  \
# 0                      True               False         False[c]       True
# 1                     False             True[f]         False[g]       True
# 2                      True             True[j]         False[k]    True[l]
# 3                      True             True[j]         False[k]    True[l]
# 4                      True               False         False[p]       True
#
#   No foreign or military failure Major foreign or military success  \
# 0                           True                             False
# 1                           True                           True[h]
# 2                           True                           True[m]
# 3                           True                           True[m]
# 4                           True                           True[q]
#
#    Charismatic incumbent Uncharismatic challenger  False keys  \
# 0                  False                  True[d]           7
# 1                  False                     True           3
# 2                   True                     True           2
# 3                  False                    False           6
# 4                   True                     True           3
#
#     Presumed winner     Actual winner
# 0   Abraham Lincoln   Abraham Lincoln
# 1   Abraham Lincoln   Abraham Lincoln
# 2  Ulysses S. Grant  Ulysses S. Grant
# 3  Ulysses S. Grant  Ulysses S. Grant
# 4  Ulysses S. Grant  Ulysses S. Grant
# Table2:
#    Election         Incumbent party nominee      Challenger party nominee  \
# 0      1984      Ronald Reagan (Republican)   Walter Mondale (Democratic)
# 1      1988  George H. W. Bush (Republican)  Michael Dukakis (Democratic)
# 2      1992  George H. W. Bush (Republican)     Bill Clinton (Democratic)
# 3      1996       Bill Clinton (Democratic)         Bob Dole (Republican)
# 4      2000            Al Gore (Democratic)   George W. Bush (Republican)
#
#    Party mandate No primary contest  Incumbent seeking re-election  \
# 0           True               True                           True
# 1           True           True[cv]                          False
# 2          False               True                           True
# 3          False               True                           True
# 4           True               True                          False
#
#   No third party Strong short-term economy  Strong long-term economy  \
# 0           True                      True                     False
# 1           True                      True                      True
# 2      False[cy]             False[cz][50]                     False
# 3      False[db]                      True                      True
# 4           True                      True                      True
#
#   Major policy change No social unrest No scandal  \
# 0            True[cu]             True       True
# 1               False             True   True[cw]
# 2               False             True       True
# 3               False             True       True
# 4               False             True  False[dc]
#
#   No foreign or military failure Major foreign or military success  \
# 0                           True                             False
# 1                           True                          True[cx]
# 2                           True                          True[da]
# 3                           True                             False
# 4                           True                             False
#
#   Charismatic incumbent  Uncharismatic challenger False keys  \
# 0                  True                      True          2
# 1                 False                      True          3
# 2                 False                      True          6
# 3                 False                      True          5
# 4                 False                      True          5
#
#     Predicted winner      Actual winner
# 0      Ronald Reagan      Ronald Reagan
# 1  George H. W. Bush  George H. W. Bush
# 2       Bill Clinton       Bill Clinton
# 3       Bill Clinton       Bill Clinton
# 4        Al Gore[dd]     George W. Bush

# %%
real_table_index = 1
real_table = tables[real_table_index]
real_table
# Out:
#    Election              Incumbent party nominee  \
# 0      1860      Stephen A. Douglas (Democratic)
# 1      1864   Abraham Lincoln (Union/Republican)
# 2   1868[i]        Ulysses S. Grant (Republican)
# 3   1868[n]         Horatio Seymour (Democratic)
# 4      1872        Ulysses S. Grant (Republican)
# 5      1876     Rutherford B. Hayes (Republican)
# 6      1880       James A. Garfield (Republican)
# 7      1884         James G. Blaine (Republican)
# 8      1888        Grover Cleveland (Democratic)
# 9      1892       Benjamin Harrison (Republican)
# 10     1896  William Jennings Bryan (Democratic)
# 11     1900        William McKinley (Republican)
# 12     1904      Theodore Roosevelt (Republican)
# 13     1908     William Howard Taft (Republican)
# 14     1912     William Howard Taft (Republican)
# 15     1916          Woodrow Wilson (Democratic)
# 16     1920            James M. Cox (Democratic)
# 17     1924         Calvin Coolidge (Republican)
# 18     1928          Herbert Hoover (Republican)
# 19     1932          Herbert Hoover (Republican)
# 20     1936   Franklin D. Roosevelt (Democratic)
# 21     1940   Franklin D. Roosevelt (Democratic)
# 22     1944   Franklin D. Roosevelt (Democratic)
# 23     1948         Harry S. Truman (Democratic)
# 24     1952      Adlai Stevenson II (Democratic)
# 25     1956    Dwight D. Eisenhower (Republican)
# 26     1960           Richard Nixon (Republican)
# 27     1964       Lyndon B. Johnson (Democratic)
# 28     1968         Hubert Humphrey (Democratic)
# 29     1972           Richard Nixon (Republican)
# 30     1976             Gerald Ford (Republican)
# 31     1980            Jimmy Carter (Democratic)
#
#                Challenger party nominee Party mandate No primary contest  \
# 0          Abraham Lincoln (Republican)          True           False[a]
# 1         George McClellan (Democratic)       True[e]               True
# 2          Horatio Seymour (Democratic)          True               True
# 3         Ulysses S. Grant (Republican)         False           False[o]
# 4     Horace Greeley (Democrat/Liberal)         False               True
# 5         Samuel J. Tilden (Democratic)         False           False[r]
# 6   Winfield Scott Hancock (Democratic)          True           False[v]
# 7         Grover Cleveland (Democratic)         False           False[x]
# 8        Benjamin Harrison (Republican)         False               True
# 9         Grover Cleveland (Democratic)         False          False[ab]
# 10        William McKinley (Republican)         False          False[af]
# 11  William Jennings Bryan (Democratic)         False               True
# 12     Alton Brooks Parker (Democratic)          True               True
# 13  William Jennings Bryan (Democratic)          True               True
# 14          Woodrow Wilson (Democratic)         False          False[aq]
# 15    Charles Evans Hughes (Republican)         False               True
# 16       Warren G. Harding (Republican)         False          False[av]
# 17           John W. Davis (Democratic)         False               True
# 18                Al Smith (Democratic)          True               True
# 19   Franklin D. Roosevelt (Democratic)         False               True
# 20              Alf Landon (Republican)          True               True
# 21         Wendell Willkie (Republican)         False               True
# 22            Thomas Dewey (Republican)         False               True
# 23            Thomas Dewey (Republican)         False           True[bn]
# 24    Dwight D. Eisenhower (Republican)          True          False[bs]
# 25      Adlai Stevenson II (Democratic)          True               True
# 26         John F. Kennedy (Democratic)         False               True
# 27         Barry Goldwater (Republican)         False               True
# 28           Richard Nixon (Republican)         False          False[cd]
# 29         George McGovern (Democratic)         False               True
# 30            Jimmy Carter (Democratic)         False          False[cl]
# 31           Ronald Reagan (Republican)         False          False[cp]
#
#     Incumbent seeking re-election No third party Strong short-term economy  \
# 0                           False       False[b]                      True
# 1                            True           True                      True
# 2                           False           True                      True
# 3                           False           True                      True
# 4                            True           True                      True
# 5                           False           True                  False[s]
# 6                           False           True                      True
# 7                           False           True                  False[y]
# 8                            True           True                      True
# 9                            True      False[ac]                      True
# 10                          False           True                 False[ag]
# 11                           True           True                      True
# 12                           True           True                      True
# 13                          False           True                  True[am]
# 14                           True      False[ar]                      True
# 15                           True           True                      True
# 16                          False           True                 False[aw]
# 17                           True      False[bb]                      True
# 18                          False           True                      True
# 19                           True           True                 False[bg]
# 20                           True           True                      True
# 21                           True           True                      True
# 22                           True           True                      True
# 23                           True      False[bo]                      True
# 24                          False           True                      True
# 25                           True           True                      True
# 26                          False           True                 False[bx]
# 27                           True           True                      True
# 28                          False      False[ce]                      True
# 29                           True           True                  True[ci]
# 30                           True           True                  True[cm]
# 31                           True      False[cq]                 False[cr]
#
#     Strong long-term economy Major policy change No social unrest No scandal  \
# 0                       True               False         False[c]       True
# 1                      False             True[f]         False[g]       True
# 2                       True             True[j]         False[k]    True[l]
# 3                       True             True[j]         False[k]    True[l]
# 4                       True               False         False[p]       True
# 5                      False               False             True   False[t]
# 6                       True             True[w]             True       True
# 7                      False               False             True       True
# 8                       True               False         False[z]       True
# 9                       True            True[ad]        False[ae]       True
# 10                     False               False        False[ah]       True
# 11                      True            True[ai]             True       True
# 12                      True            True[ak]             True       True
# 13                     False            True[an]             True       True
# 14                      True               False             True       True
# 15                     False            True[at]             True       True
# 16                     False            True[ax]        False[ay]       True
# 17                      True            True[bc]             True  False[bd]
# 18                      True               False             True       True
# 19                     False               False        False[bh]       True
# 20                      True            True[bi]             True       True
# 21                      True            True[bj]             True       True
# 22                      True            True[bk]             True       True
# 23                     False            True[bp]             True       True
# 24                     False               False             True  False[bt]
# 25                      True               False             True       True
# 26                     False               False             True       True
# 27                      True            True[ca]             True       True
# 28                      True            True[cf]        False[cg]       True
# 29                     False               False             True   True[cj]
# 30                     False               False             True  False[cn]
# 31                      True               False             True       True
#
#    No foreign or military failure Major foreign or military success  \
# 0                            True                             False
# 1                            True                           True[h]
# 2                            True                           True[m]
# 3                            True                           True[m]
# 4                            True                           True[q]
# 5                            True                             False
# 6                            True                             False
# 7                            True                             False
# 8                            True                             False
# 9                            True                             False
# 10                           True                             False
# 11                           True                          True[aj]
# 12                           True                          True[al]
# 13                           True                          True[ao]
# 14                           True                             False
# 15                           True                          True[au]
# 16                      False[az]                          True[ba]
# 17                           True                          True[be]
# 18                           True                          True[bf]
# 19                           True                             False
# 20                           True                             False
# 21                           True                             False
# 22                      False[bl]                          True[bm]
# 23                      False[bq]                          True[br]
# 24                      False[bu]                          True[bv]
# 25                           True                          True[bw]
# 26                      False[by]                             False
# 27                      False[cb]                          True[cc]
# 28                      False[ch]                             False
# 29                           True                          True[ck]
# 30                      False[co]                             False
# 31                      False[cs]                          True[ct]
#
#     Charismatic incumbent Uncharismatic challenger  False keys  \
# 0                   False                  True[d]           7
# 1                   False                     True           3
# 2                    True                     True           2
# 3                   False                    False           6
# 4                    True                     True           3
# 5                   False                     True           9
# 6                   False                     True           4
# 7                    True                     True           7
# 8                   False                     True           5
# 9                   False                     True           6
# 10                   True                     True           8
# 11                  False                    False           3
# 12                   True                     True           0
# 13                  False                 True[ap]           3
# 14                  False                     True           6
# 15                  False                     True           3
# 16                  False                     True           8
# 17                  False                     True           4
# 18                  False                     True           3
# 19                  False                    False           8
# 20                   True                     True           1
# 21                   True                     True           2
# 22                   True                     True           2
# 23                  False                     True           5
# 24                  False                    False           8
# 25                   True                     True           1
# 26                  False                    False           9
# 27                  False                     True           3
# 28                  False                     True           8
# 29                  False                     True           4
# 30                  False                     True           8
# 31                  False                    False           8
#
#           Presumed winner          Actual winner
# 0         Abraham Lincoln        Abraham Lincoln
# 1         Abraham Lincoln        Abraham Lincoln
# 2        Ulysses S. Grant       Ulysses S. Grant
# 3        Ulysses S. Grant       Ulysses S. Grant
# 4        Ulysses S. Grant       Ulysses S. Grant
# 5     Samuel J. Tilden[u]    Rutherford B. Hayes
# 6       James A. Garfield      James A. Garfield
# 7        Grover Cleveland       Grover Cleveland
# 8    Grover Cleveland[aa]      Benjamin Harrison
# 9        Grover Cleveland       Grover Cleveland
# 10       William McKinley       William McKinley
# 11       William McKinley       William McKinley
# 12     Theodore Roosevelt     Theodore Roosevelt
# 13    William Howard Taft    William Howard Taft
# 14     Woodrow Wilson[as]     Woodrow Wilson[as]
# 15         Woodrow Wilson         Woodrow Wilson
# 16      Warren G. Harding      Warren G. Harding
# 17        Calvin Coolidge        Calvin Coolidge
# 18         Herbert Hoover         Herbert Hoover
# 19  Franklin D. Roosevelt  Franklin D. Roosevelt
# 20  Franklin D. Roosevelt  Franklin D. Roosevelt
# 21  Franklin D. Roosevelt  Franklin D. Roosevelt
# 22  Franklin D. Roosevelt  Franklin D. Roosevelt
# 23        Harry S. Truman        Harry S. Truman
# 24   Dwight D. Eisenhower   Dwight D. Eisenhower
# 25   Dwight D. Eisenhower   Dwight D. Eisenhower
# 26    John F. Kennedy[bz]    John F. Kennedy[bz]
# 27      Lyndon B. Johnson      Lyndon B. Johnson
# 28          Richard Nixon          Richard Nixon
# 29          Richard Nixon          Richard Nixon
# 30           Jimmy Carter           Jimmy Carter
# 31          Ronald Reagan          Ronald Reagan

# %%
real_table.drop([2,3], inplace=True) #drop two that have different format

# %%
real_table.reset_index(drop=True, inplace=True)
real_table #reset the indexes from the drop
# Out:
#    Election              Incumbent party nominee  \
# 0      1860      Stephen A. Douglas (Democratic)
# 1      1864   Abraham Lincoln (Union/Republican)
# 2      1872        Ulysses S. Grant (Republican)
# 3      1876     Rutherford B. Hayes (Republican)
# 4      1880       James A. Garfield (Republican)
# 5      1884         James G. Blaine (Republican)
# 6      1888        Grover Cleveland (Democratic)
# 7      1892       Benjamin Harrison (Republican)
# 8      1896  William Jennings Bryan (Democratic)
# 9      1900        William McKinley (Republican)
# 10     1904      Theodore Roosevelt (Republican)
# 11     1908     William Howard Taft (Republican)
# 12     1912     William Howard Taft (Republican)
# 13     1916          Woodrow Wilson (Democratic)
# 14     1920            James M. Cox (Democratic)
# 15     1924         Calvin Coolidge (Republican)
# 16     1928          Herbert Hoover (Republican)
# 17     1932          Herbert Hoover (Republican)
# 18     1936   Franklin D. Roosevelt (Democratic)
# 19     1940   Franklin D. Roosevelt (Democratic)
# 20     1944   Franklin D. Roosevelt (Democratic)
# 21     1948         Harry S. Truman (Democratic)
# 22     1952      Adlai Stevenson II (Democratic)
# 23     1956    Dwight D. Eisenhower (Republican)
# 24     1960           Richard Nixon (Republican)
# 25     1964       Lyndon B. Johnson (Democratic)
# 26     1968         Hubert Humphrey (Democratic)
# 27     1972           Richard Nixon (Republican)
# 28     1976             Gerald Ford (Republican)
# 29     1980            Jimmy Carter (Democratic)
#
#                Challenger party nominee Party mandate No primary contest  \
# 0          Abraham Lincoln (Republican)          True           False[a]
# 1         George McClellan (Democratic)       True[e]               True
# 2     Horace Greeley (Democrat/Liberal)         False               True
# 3         Samuel J. Tilden (Democratic)         False           False[r]
# 4   Winfield Scott Hancock (Democratic)          True           False[v]
# 5         Grover Cleveland (Democratic)         False           False[x]
# 6        Benjamin Harrison (Republican)         False               True
# 7         Grover Cleveland (Democratic)         False          False[ab]
# 8         William McKinley (Republican)         False          False[af]
# 9   William Jennings Bryan (Democratic)         False               True
# 10     Alton Brooks Parker (Democratic)          True               True
# 11  William Jennings Bryan (Democratic)          True               True
# 12          Woodrow Wilson (Democratic)         False          False[aq]
# 13    Charles Evans Hughes (Republican)         False               True
# 14       Warren G. Harding (Republican)         False          False[av]
# 15           John W. Davis (Democratic)         False               True
# 16                Al Smith (Democratic)          True               True
# 17   Franklin D. Roosevelt (Democratic)         False               True
# 18              Alf Landon (Republican)          True               True
# 19         Wendell Willkie (Republican)         False               True
# 20            Thomas Dewey (Republican)         False               True
# 21            Thomas Dewey (Republican)         False           True[bn]
# 22    Dwight D. Eisenhower (Republican)          True          False[bs]
# 23      Adlai Stevenson II (Democratic)          True               True
# 24         John F. Kennedy (Democratic)         False               True
# 25         Barry Goldwater (Republican)         False               True
# 26           Richard Nixon (Republican)         False          False[cd]
# 27         George McGovern (Democratic)         False               True
# 28            Jimmy Carter (Democratic)         False          False[cl]
# 29           Ronald Reagan (Republican)         False          False[cp]
#
#     Incumbent seeking re-election No third party Strong short-term economy  \
# 0                           False       False[b]                      True
# 1                            True           True                      True
# 2                            True           True                      True
# 3                           False           True                  False[s]
# 4                           False           True                      True
# 5                           False           True                  False[y]
# 6                            True           True                      True
# 7                            True      False[ac]                      True
# 8                           False           True                 False[ag]
# 9                            True           True                      True
# 10                           True           True                      True
# 11                          False           True                  True[am]
# 12                           True      False[ar]                      True
# 13                           True           True                      True
# 14                          False           True                 False[aw]
# 15                           True      False[bb]                      True
# 16                          False           True                      True
# 17                           True           True                 False[bg]
# 18                           True           True                      True
# 19                           True           True                      True
# 20                           True           True                      True
# 21                           True      False[bo]                      True
# 22                          False           True                      True
# 23                           True           True                      True
# 24                          False           True                 False[bx]
# 25                           True           True                      True
# 26                          False      False[ce]                      True
# 27                           True           True                  True[ci]
# 28                           True           True                  True[cm]
# 29                           True      False[cq]                 False[cr]
#
#     Strong long-term economy Major policy change No social unrest No scandal  \
# 0                       True               False         False[c]       True
# 1                      False             True[f]         False[g]       True
# 2                       True               False         False[p]       True
# 3                      False               False             True   False[t]
# 4                       True             True[w]             True       True
# 5                      False               False             True       True
# 6                       True               False         False[z]       True
# 7                       True            True[ad]        False[ae]       True
# 8                      False               False        False[ah]       True
# 9                       True            True[ai]             True       True
# 10                      True            True[ak]             True       True
# 11                     False            True[an]             True       True
# 12                      True               False             True       True
# 13                     False            True[at]             True       True
# 14                     False            True[ax]        False[ay]       True
# 15                      True            True[bc]             True  False[bd]
# 16                      True               False             True       True
# 17                     False               False        False[bh]       True
# 18                      True            True[bi]             True       True
# 19                      True            True[bj]             True       True
# 20                      True            True[bk]             True       True
# 21                     False            True[bp]             True       True
# 22                     False               False             True  False[bt]
# 23                      True               False             True       True
# 24                     False               False             True       True
# 25                      True            True[ca]             True       True
# 26                      True            True[cf]        False[cg]       True
# 27                     False               False             True   True[cj]
# 28                     False               False             True  False[cn]
# 29                      True               False             True       True
#
#    No foreign or military failure Major foreign or military success  \
# 0                            True                             False
# 1                            True                           True[h]
# 2                            True                           True[q]
# 3                            True                             False
# 4                            True                             False
# 5                            True                             False
# 6                            True                             False
# 7                            True                             False
# 8                            True                             False
# 9                            True                          True[aj]
# 10                           True                          True[al]
# 11                           True                          True[ao]
# 12                           True                             False
# 13                           True                          True[au]
# 14                      False[az]                          True[ba]
# 15                           True                          True[be]
# 16                           True                          True[bf]
# 17                           True                             False
# 18                           True                             False
# 19                           True                             False
# 20                      False[bl]                          True[bm]
# 21                      False[bq]                          True[br]
# 22                      False[bu]                          True[bv]
# 23                           True                          True[bw]
# 24                      False[by]                             False
# 25                      False[cb]                          True[cc]
# 26                      False[ch]                             False
# 27                           True                          True[ck]
# 28                      False[co]                             False
# 29                      False[cs]                          True[ct]
#
#     Charismatic incumbent Uncharismatic challenger  False keys  \
# 0                   False                  True[d]           7
# 1                   False                     True           3
# 2                    True                     True           3
# 3                   False                     True           9
# 4                   False                     True           4
# 5                    True                     True           7
# 6                   False                     True           5
# 7                   False                     True           6
# 8                    True                     True           8
# 9                   False                    False           3
# 10                   True                     True           0
# 11                  False                 True[ap]           3
# 12                  False                     True           6
# 13                  False                     True           3
# 14                  False                     True           8
# 15                  False                     True           4
# 16                  False                     True           3
# 17                  False                    False           8
# 18                   True                     True           1
# 19                   True                     True           2
# 20                   True                     True           2
# 21                  False                     True           5
# 22                  False                    False           8
# 23                   True                     True           1
# 24                  False                    False           9
# 25                  False                     True           3
# 26                  False                     True           8
# 27                  False                     True           4
# 28                  False                     True           8
# 29                  False                    False           8
#
#           Presumed winner          Actual winner
# 0         Abraham Lincoln        Abraham Lincoln
# 1         Abraham Lincoln        Abraham Lincoln
# 2        Ulysses S. Grant       Ulysses S. Grant
# 3     Samuel J. Tilden[u]    Rutherford B. Hayes
# 4       James A. Garfield      James A. Garfield
# 5        Grover Cleveland       Grover Cleveland
# 6    Grover Cleveland[aa]      Benjamin Harrison
# 7        Grover Cleveland       Grover Cleveland
# 8        William McKinley       William McKinley
# 9        William McKinley       William McKinley
# 10     Theodore Roosevelt     Theodore Roosevelt
# 11    William Howard Taft    William Howard Taft
# 12     Woodrow Wilson[as]     Woodrow Wilson[as]
# 13         Woodrow Wilson         Woodrow Wilson
# 14      Warren G. Harding      Warren G. Harding
# 15        Calvin Coolidge        Calvin Coolidge
# 16         Herbert Hoover         Herbert Hoover
# 17  Franklin D. Roosevelt  Franklin D. Roosevelt
# 18  Franklin D. Roosevelt  Franklin D. Roosevelt
# 19  Franklin D. Roosevelt  Franklin D. Roosevelt
# 20  Franklin D. Roosevelt  Franklin D. Roosevelt
# 21        Harry S. Truman        Harry S. Truman
# 22   Dwight D. Eisenhower   Dwight D. Eisenhower
# 23   Dwight D. Eisenhower   Dwight D. Eisenhower
# 24    John F. Kennedy[bz]    John F. Kennedy[bz]
# 25      Lyndon B. Johnson      Lyndon B. Johnson
# 26          Richard Nixon          Richard Nixon
# 27          Richard Nixon          Richard Nixon
# 28           Jimmy Carter           Jimmy Carter
# 29          Ronald Reagan          Ronald Reagan

# %%
real_table["Election"] = real_table["Election"].astype(int)
bs1 = real_table[real_table['Election'] >= 1976]
bs1 #bs1 has data from one table of the tables that we wanted
# Out:
#     Election    Incumbent party nominee    Challenger party nominee  \
# 28      1976   Gerald Ford (Republican)   Jimmy Carter (Democratic)
# 29      1980  Jimmy Carter (Democratic)  Ronald Reagan (Republican)
#
#    Party mandate No primary contest  Incumbent seeking re-election  \
# 28         False          False[cl]                           True
# 29         False          False[cp]                           True
#
#    No third party Strong short-term economy  Strong long-term economy  \
# 28           True                  True[cm]                     False
# 29      False[cq]                 False[cr]                      True
#
#    Major policy change No social unrest No scandal  \
# 28               False             True  False[cn]
# 29               False             True       True
#
#    No foreign or military failure Major foreign or military success  \
# 28                      False[co]                             False
# 29                      False[cs]                          True[ct]
#
#     Charismatic incumbent Uncharismatic challenger  False keys  \
# 28                  False                     True           8
# 29                  False                    False           8
#
#    Presumed winner  Actual winner
# 28    Jimmy Carter   Jimmy Carter
# 29   Ronald Reagan  Ronald Reagan

# %%
real_table_index2 = 2
real_table2 = tables[real_table_index2]
real_table2
# Out:
#     Election         Incumbent party nominee      Challenger party nominee  \
# 0       1984      Ronald Reagan (Republican)   Walter Mondale (Democratic)
# 1       1988  George H. W. Bush (Republican)  Michael Dukakis (Democratic)
# 2       1992  George H. W. Bush (Republican)     Bill Clinton (Democratic)
# 3       1996       Bill Clinton (Democratic)         Bob Dole (Republican)
# 4       2000            Al Gore (Democratic)   George W. Bush (Republican)
# 5       2004     George W. Bush (Republican)       John Kerry (Democratic)
# 6       2008        John McCain (Republican)     Barack Obama (Democratic)
# 7       2012       Barack Obama (Democratic)      Mitt Romney (Republican)
# 8       2016    Hillary Clinton (Democratic)     Donald Trump (Republican)
# 9       2020       Donald Trump (Republican)        Joe Biden (Democratic)
# 10      2024      Kamala Harris (Democratic)     Donald Trump (Republican)
#
#     Party mandate No primary contest  Incumbent seeking re-election  \
# 0            True               True                           True
# 1            True           True[cv]                          False
# 2           False               True                           True
# 3           False               True                           True
# 4            True               True                          False
# 5            True               True                           True
# 6           False           True[dg]                          False
# 7           False               True                           True
# 8           False          False[dm]                          False
# 9           False               True                           True
# 10          False               True                          False
#
#    No third party Strong short-term economy  Strong long-term economy  \
# 0            True                      True                     False
# 1            True                      True                      True
# 2       False[cy]             False[cz][50]                     False
# 3       False[db]                      True                      True
# 4            True                      True                      True
# 5            True                      True                     False
# 6            True                 False[dh]                     False
# 7            True                      True                     False
# 8        True[dn]                      True                      True
# 9            True                 False[dq]                     False
# 10           True                      True                      True
#
#    Major policy change No social unrest No scandal  \
# 0             True[cu]             True       True
# 1                False             True   True[cw]
# 2                False             True       True
# 3                False             True       True
# 4                False             True  False[dc]
# 5                False             True       True
# 6                False             True       True
# 7             True[dj]             True       True
# 8                False             True       True
# 9             True[dr]        False[ds]  False[dt]
# 10            True[du]             True       True
#
#    No foreign or military failure Major foreign or military success  \
# 0                            True                             False
# 1                            True                          True[cx]
# 2                            True                          True[da]
# 3                            True                             False
# 4                            True                             False
# 5                       False[de]                          True[df]
# 6                       False[di]                             False
# 7                            True                          True[dk]
# 8                            True                             False
# 9                            True                             False
# 10                  False[dv][54]                      True[dw][55]
#
#    Charismatic incumbent  Uncharismatic challenger False keys  \
# 0                   True                      True          2
# 1                  False                      True          3
# 2                  False                      True          6
# 3                  False                      True          5
# 4                  False                      True          5
# 5                  False                      True          4
# 6                  False                     False          9
# 7              False[dl]                      True          3
# 8                  False                      True      6[do]
# 9                  False                      True          7
# 10                 False                      True          4
#
#            Predicted winner            Actual winner
# 0             Ronald Reagan            Ronald Reagan
# 1         George H. W. Bush        George H. W. Bush
# 2              Bill Clinton             Bill Clinton
# 3              Bill Clinton             Bill Clinton
# 4               Al Gore[dd]           George W. Bush
# 5            George W. Bush           George W. Bush
# 6              Barack Obama             Barack Obama
# 7              Barack Obama             Barack Obama
# 8   Donald Trump[dp][6][52]  Donald Trump[dp][6][52]
# 9             Joe Biden[53]            Joe Biden[53]
# 10        Kamala Harris[56]                      TBD

# %%
bs2 = real_table2

# %%
bs_combined = pd.concat([bs1, bs2], axis = 0)
bs_combined = bs_combined.reset_index(drop=True)
bs_combined
# Out:
#     Election         Incumbent party nominee      Challenger party nominee  \
# 0       1976        Gerald Ford (Republican)     Jimmy Carter (Democratic)
# 1       1980       Jimmy Carter (Democratic)    Ronald Reagan (Republican)
# 2       1984      Ronald Reagan (Republican)   Walter Mondale (Democratic)
# 3       1988  George H. W. Bush (Republican)  Michael Dukakis (Democratic)
# 4       1992  George H. W. Bush (Republican)     Bill Clinton (Democratic)
# 5       1996       Bill Clinton (Democratic)         Bob Dole (Republican)
# 6       2000            Al Gore (Democratic)   George W. Bush (Republican)
# 7       2004     George W. Bush (Republican)       John Kerry (Democratic)
# 8       2008        John McCain (Republican)     Barack Obama (Democratic)
# 9       2012       Barack Obama (Democratic)      Mitt Romney (Republican)
# 10      2016    Hillary Clinton (Democratic)     Donald Trump (Republican)
# 11      2020       Donald Trump (Republican)        Joe Biden (Democratic)
# 12      2024      Kamala Harris (Democratic)     Donald Trump (Republican)
#
#    Party mandate No primary contest  Incumbent seeking re-election  \
# 0          False          False[cl]                           True
# 1          False          False[cp]                           True
# 2           True               True                           True
# 3           True           True[cv]                          False
# 4          False               True                           True
# 5          False               True                           True
# 6           True               True                          False
# 7           True               True                           True
# 8          False           True[dg]                          False
# 9          False               True                           True
# 10         False          False[dm]                          False
# 11         False               True                           True
# 12         False               True                          False
#
#    No third party Strong short-term economy  Strong long-term economy  \
# 0            True                  True[cm]                     False
# 1       False[cq]                 False[cr]                      True
# 2            True                      True                     False
# 3            True                      True                      True
# 4       False[cy]             False[cz][50]                     False
# 5       False[db]                      True                      True
# 6            True                      True                      True
# 7            True                      True                     False
# 8            True                 False[dh]                     False
# 9            True                      True                     False
# 10       True[dn]                      True                      True
# 11           True                 False[dq]                     False
# 12           True                      True                      True
#
#    Major policy change No social unrest No scandal  \
# 0                False             True  False[cn]
# 1                False             True       True
# 2             True[cu]             True       True
# 3                False             True   True[cw]
# 4                False             True       True
# 5                False             True       True
# 6                False             True  False[dc]
# 7                False             True       True
# 8                False             True       True
# 9             True[dj]             True       True
# 10               False             True       True
# 11            True[dr]        False[ds]  False[dt]
# 12            True[du]             True       True
#
#    No foreign or military failure Major foreign or military success  \
# 0                       False[co]                             False
# 1                       False[cs]                          True[ct]
# 2                            True                             False
# 3                            True                          True[cx]
# 4                            True                          True[da]
# 5                            True                             False
# 6                            True                             False
# 7                       False[de]                          True[df]
# 8                       False[di]                             False
# 9                            True                          True[dk]
# 10                           True                             False
# 11                           True                             False
# 12                  False[dv][54]                      True[dw][55]
#
#    Charismatic incumbent Uncharismatic challenger False keys Presumed winner  \
# 0                  False                     True          8    Jimmy Carter
# 1                  False                    False          8   Ronald Reagan
# 2                   True                     True          2             NaN
# 3                  False                     True          3             NaN
# 4                  False                     True          6             NaN
# 5                  False                     True          5             NaN
# 6                  False                     True          5             NaN
# 7                  False                     True          4             NaN
# 8                  False                    False          9             NaN
# 9              False[dl]                     True          3             NaN
# 10                 False                     True      6[do]             NaN
# 11                 False                     True          7             NaN
# 12                 False                     True          4             NaN
#
#               Actual winner         Predicted winner
# 0              Jimmy Carter                      NaN
# 1             Ronald Reagan                      NaN
# 2             Ronald Reagan            Ronald Reagan
# 3         George H. W. Bush        George H. W. Bush
# 4              Bill Clinton             Bill Clinton
# 5              Bill Clinton             Bill Clinton
# 6            George W. Bush              Al Gore[dd]
# 7            George W. Bush           George W. Bush
# 8              Barack Obama             Barack Obama
# 9              Barack Obama             Barack Obama
# 10  Donald Trump[dp][6][52]  Donald Trump[dp][6][52]
# 11            Joe Biden[53]            Joe Biden[53]
# 12                      TBD        Kamala Harris[56]

# %%
bs_combined_1 = bs_combined.drop("Presumed winner", axis=1)#dropar a coluna presumed winner almost no info
bs_combined_1
# Out:
#     Election         Incumbent party nominee      Challenger party nominee  \
# 0       1976        GERALD FORD (REPUBLICAN)     JIMMY CARTER (DEMOCRATIC)
# 1       1980       JIMMY CARTER (DEMOCRATIC)    RONALD REAGAN (REPUBLICAN)
# 2       1984      RONALD REAGAN (REPUBLICAN)   WALTER MONDALE (DEMOCRATIC)
# 3       1988  GEORGE H. W. BUSH (REPUBLICAN)  MICHAEL DUKAKIS (DEMOCRATIC)
# 4       1992  GEORGE H. W. BUSH (REPUBLICAN)     BILL CLINTON (DEMOCRATIC)
# 5       1996       BILL CLINTON (DEMOCRATIC)         BOB DOLE (REPUBLICAN)
# 6       2000            AL GORE (DEMOCRATIC)   GEORGE W. BUSH (REPUBLICAN)
# 7       2004     GEORGE W. BUSH (REPUBLICAN)       JOHN KERRY (DEMOCRATIC)
# 8       2008        JOHN MCCAIN (REPUBLICAN)     BARACK OBAMA (DEMOCRATIC)
# 9       2012       BARACK OBAMA (DEMOCRATIC)      MITT ROMNEY (REPUBLICAN)
# 10      2016    HILLARY CLINTON (DEMOCRATIC)     DONALD TRUMP (REPUBLICAN)
# 11      2020       DONALD TRUMP (REPUBLICAN)        JOE BIDEN (DEMOCRATIC)
# 12      2024      KAMALA HARRIS (DEMOCRATIC)     DONALD TRUMP (REPUBLICAN)
#
#    Party mandate No primary contest  Incumbent seeking re-election  \
# 0          False          False[cl]                           True
# 1          False          False[cp]                           True
# 2           True               True                           True
# 3           True           True[cv]                          False
# 4          False               True                           True
# 5          False               True                           True
# 6           True               True                          False
# 7           True               True                           True
# 8          False           True[dg]                          False
# 9          False               True                           True
# 10         False          False[dm]                          False
# 11         False               True                           True
# 12         False               True                          False
#
#    No third party Strong short-term economy  Strong long-term economy  \
# 0            True                  True[cm]                     False
# 1       False[cq]                 False[cr]                      True
# 2            True                      True                     False
# 3            True                      True                      True
# 4       False[cy]             False[cz][50]                     False
# 5       False[db]                      True                      True
# 6            True                      True                      True
# 7            True                      True                     False
# 8            True                 False[dh]                     False
# 9            True                      True                     False
# 10       True[dn]                      True                      True
# 11           True                 False[dq]                     False
# 12           True                      True                      True
#
#    Major policy change No social unrest No scandal  \
# 0                False             True  False[cn]
# 1                False             True       True
# 2             True[cu]             True       True
# 3                False             True   True[cw]
# 4                False             True       True
# 5                False             True       True
# 6                False             True  False[dc]
# 7                False             True       True
# 8                False             True       True
# 9             True[dj]             True       True
# 10               False             True       True
# 11            True[dr]        False[ds]  False[dt]
# 12            True[du]             True       True
#
#    No foreign or military failure Major foreign or military success  \
# 0                       False[co]                             False
# 1                       False[cs]                          True[ct]
# 2                            True                             False
# 3                            True                          True[cx]
# 4                            True                          True[da]
# 5                            True                             False
# 6                            True                             False
# 7                       False[de]                          True[df]
# 8                       False[di]                             False
# 9                            True                          True[dk]
# 10                           True                             False
# 11                           True                             False
# 12                  False[dv][54]                      True[dw][55]
#
#    Charismatic incumbent Uncharismatic challenger False keys  \
# 0                  False                     True          8
# 1                  False                    False          8
# 2                   True                     True          2
# 3                  False                     True          3
# 4                  False                     True          6
# 5                  False                     True          5
# 6                  False                     True          5
# 7                  False                     True          4
# 8                  False                    False          9
# 9              False[dl]                     True          3
# 10                 False                     True      6[do]
# 11                 False                     True          7
# 12                 False                     True          4
#
#               Actual winner         Predicted winner
# 0              Jimmy Carter                      NaN
# 1             Ronald Reagan                      NaN
# 2             Ronald Reagan            Ronald Reagan
# 3         George H. W. Bush        George H. W. Bush
# 4              Bill Clinton             Bill Clinton
# 5              Bill Clinton             Bill Clinton
# 6            George W. Bush              Al Gore[dd]
# 7            George W. Bush           George W. Bush
# 8              Barack Obama             Barack Obama
# 9              Barack Obama             Barack Obama
# 10  Donald Trump[dp][6][52]  Donald Trump[dp][6][52]
# 11            Joe Biden[53]            Joe Biden[53]
# 12                      TBD        Kamala Harris[56]

# %%
bs_combined_1['Incumbent party nominee'] = bs_combined_1['Incumbent party nominee'].str.upper()
bs_combined_1['Challenger party nominee'] = bs_combined_1['Challenger party nominee'].str.upper()
bs_combined_1['Actual winner'] = bs_combined_1['Actual winner'].str.upper()
bs_combined_1['Predicted winner'] = bs_combined['Predicted winner'].str.upper()
bs_combined_1
# Out:
#     Election         Incumbent party nominee      Challenger party nominee  \
# 0       1976        GERALD FORD (REPUBLICAN)     JIMMY CARTER (DEMOCRATIC)
# 1       1980       JIMMY CARTER (DEMOCRATIC)    RONALD REAGAN (REPUBLICAN)
# 2       1984      RONALD REAGAN (REPUBLICAN)   WALTER MONDALE (DEMOCRATIC)
# 3       1988  GEORGE H. W. BUSH (REPUBLICAN)  MICHAEL DUKAKIS (DEMOCRATIC)
# 4       1992  GEORGE H. W. BUSH (REPUBLICAN)     BILL CLINTON (DEMOCRATIC)
# 5       1996       BILL CLINTON (DEMOCRATIC)         BOB DOLE (REPUBLICAN)
# 6       2000            AL GORE (DEMOCRATIC)   GEORGE W. BUSH (REPUBLICAN)
# 7       2004     GEORGE W. BUSH (REPUBLICAN)       JOHN KERRY (DEMOCRATIC)
# 8       2008        JOHN MCCAIN (REPUBLICAN)     BARACK OBAMA (DEMOCRATIC)
# 9       2012       BARACK OBAMA (DEMOCRATIC)      MITT ROMNEY (REPUBLICAN)
# 10      2016    HILLARY CLINTON (DEMOCRATIC)     DONALD TRUMP (REPUBLICAN)
# 11      2020       DONALD TRUMP (REPUBLICAN)        JOE BIDEN (DEMOCRATIC)
# 12      2024      KAMALA HARRIS (DEMOCRATIC)     DONALD TRUMP (REPUBLICAN)
#
#    Party mandate No primary contest  Incumbent seeking re-election  \
# 0          False          False[cl]                           True
# 1          False          False[cp]                           True
# 2           True               True                           True
# 3           True           True[cv]                          False
# 4          False               True                           True
# 5          False               True                           True
# 6           True               True                          False
# 7           True               True                           True
# 8          False           True[dg]                          False
# 9          False               True                           True
# 10         False          False[dm]                          False
# 11         False               True                           True
# 12         False               True                          False
#
#    No third party Strong short-term economy  Strong long-term economy  \
# 0            True                  True[cm]                     False
# 1       False[cq]                 False[cr]                      True
# 2            True                      True                     False
# 3            True                      True                      True
# 4       False[cy]             False[cz][50]                     False
# 5       False[db]                      True                      True
# 6            True                      True                      True
# 7            True                      True                     False
# 8            True                 False[dh]                     False
# 9            True                      True                     False
# 10       True[dn]                      True                      True
# 11           True                 False[dq]                     False
# 12           True                      True                      True
#
#    Major policy change No social unrest No scandal  \
# 0                False             True  False[cn]
# 1                False             True       True
# 2             True[cu]             True       True
# 3                False             True   True[cw]
# 4                False             True       True
# 5                False             True       True
# 6                False             True  False[dc]
# 7                False             True       True
# 8                False             True       True
# 9             True[dj]             True       True
# 10               False             True       True
# 11            True[dr]        False[ds]  False[dt]
# 12            True[du]             True       True
#
#    No foreign or military failure Major foreign or military success  \
# 0                       False[co]                             False
# 1                       False[cs]                          True[ct]
# 2                            True                             False
# 3                            True                          True[cx]
# 4                            True                          True[da]
# 5                            True                             False
# 6                            True                             False
# 7                       False[de]                          True[df]
# 8                       False[di]                             False
# 9                            True                          True[dk]
# 10                           True                             False
# 11                           True                             False
# 12                  False[dv][54]                      True[dw][55]
#
#    Charismatic incumbent Uncharismatic challenger False keys  \
# 0                  False                     True          8
# 1                  False                    False          8
# 2                   True                     True          2
# 3                  False                     True          3
# 4                  False                     True          6
# 5                  False                     True          5
# 6                  False                     True          5
# 7                  False                     True          4
# 8                  False                    False          9
# 9              False[dl]                     True          3
# 10                 False                     True      6[do]
# 11                 False                     True          7
# 12                 False                     True          4
#
#               Actual winner         Predicted winner
# 0              JIMMY CARTER                      NaN
# 1             RONALD REAGAN                      NaN
# 2             RONALD REAGAN            RONALD REAGAN
# 3         GEORGE H. W. BUSH        GEORGE H. W. BUSH
# 4              BILL CLINTON             BILL CLINTON
# 5              BILL CLINTON             BILL CLINTON
# 6            GEORGE W. BUSH              AL GORE[DD]
# 7            GEORGE W. BUSH           GEORGE W. BUSH
# 8              BARACK OBAMA             BARACK OBAMA
# 9              BARACK OBAMA             BARACK OBAMA
# 10  DONALD TRUMP[DP][6][52]  DONALD TRUMP[DP][6][52]
# 11            JOE BIDEN[53]            JOE BIDEN[53]
# 12                      TBD        KAMALA HARRIS[56]

# %%
bs_combined_1['year'] = bs_combined_1['Election'].astype(int)
bs_combined_2 = bs_combined_1.drop("Election", axis=1)
df_final_1['year'] = df_final_1['year'].astype(int)

# %% [markdown]
# ***

# %% [markdown]
# - 1976-2020_public_dataset + Allan Lichtman Keys 🫱🏾‍🫲🏻

# %%
bs_combined_1
df_combination = df_final_1.merge(bs_combined_1, on='year', how='left')
df_combination
# Out:
#       year          state            candidate  candidatevotes  totalvotes  \
# 0     1976        ALABAMA        CARTER, JIMMY          659170     1182850
# 1     1976        ALABAMA         FORD, GERALD          504070     1182850
# 2     1976         ALASKA         FORD, GERALD           71555      123574
# 3     1976         ALASKA        CARTER, JIMMY           44058      123574
# 4     1976        ARIZONA         FORD, GERALD          418642      742719
# ...    ...            ...                  ...             ...         ...
# 1222  2020  WEST VIRGINIA     TRUMP, DONALD J.          545382      794652
# 1223  2020      WISCONSIN  BIDEN, JOSEPH R. JR         1630866     3298041
# 1224  2020      WISCONSIN     TRUMP, DONALD J.         1610184     3298041
# 1225  2020        WYOMING  BIDEN, JOSEPH R. JR           73491      278503
# 1226  2020        WYOMING     TRUMP, DONALD J.          193559      278503
#
#      party_simplified  vote_percentage  Election    Incumbent party nominee  \
# 0            DEMOCRAT        55.727269      1976   GERALD FORD (REPUBLICAN)
# 1          REPUBLICAN        42.614871      1976   GERALD FORD (REPUBLICAN)
# 2          REPUBLICAN        57.904575      1976   GERALD FORD (REPUBLICAN)
# 3            DEMOCRAT        35.653131      1976   GERALD FORD (REPUBLICAN)
# 4          REPUBLICAN        56.366136      1976   GERALD FORD (REPUBLICAN)
# ...               ...              ...       ...                        ...
# 1222       REPUBLICAN        68.631552      2020  DONALD TRUMP (REPUBLICAN)
# 1223         DEMOCRAT        49.449537      2020  DONALD TRUMP (REPUBLICAN)
# 1224       REPUBLICAN        48.822437      2020  DONALD TRUMP (REPUBLICAN)
# 1225         DEMOCRAT        26.387867      2020  DONALD TRUMP (REPUBLICAN)
# 1226       REPUBLICAN        69.499790      2020  DONALD TRUMP (REPUBLICAN)
#
#        Challenger party nominee  ... Major policy change No social unrest  \
# 0     JIMMY CARTER (DEMOCRATIC)  ...               False             True
# 1     JIMMY CARTER (DEMOCRATIC)  ...               False             True
# 2     JIMMY CARTER (DEMOCRATIC)  ...               False             True
# 3     JIMMY CARTER (DEMOCRATIC)  ...               False             True
# 4     JIMMY CARTER (DEMOCRATIC)  ...               False             True
# ...                         ...  ...                 ...              ...
# 1222     JOE BIDEN (DEMOCRATIC)  ...            True[dr]        False[ds]
# 1223     JOE BIDEN (DEMOCRATIC)  ...            True[dr]        False[ds]
# 1224     JOE BIDEN (DEMOCRATIC)  ...            True[dr]        False[ds]
# 1225     JOE BIDEN (DEMOCRATIC)  ...            True[dr]        False[ds]
# 1226     JOE BIDEN (DEMOCRATIC)  ...            True[dr]        False[ds]
#
#       No scandal No foreign or military failure  \
# 0      False[cn]                      False[co]
# 1      False[cn]                      False[co]
# 2      False[cn]                      False[co]
# 3      False[cn]                      False[co]
# 4      False[cn]                      False[co]
# ...          ...                            ...
# 1222   False[dt]                           True
# 1223   False[dt]                           True
# 1224   False[dt]                           True
# 1225   False[dt]                           True
# 1226   False[dt]                           True
#
#      Major foreign or military success  Charismatic incumbent  \
# 0                                False                  False
# 1                                False                  False
# 2                                False                  False
# 3                                False                  False
# 4                                False                  False
# ...                                ...                    ...
# 1222                             False                  False
# 1223                             False                  False
# 1224                             False                  False
# 1225                             False                  False
# 1226                             False                  False
#
#      Uncharismatic challenger False keys  Actual winner Predicted winner
# 0                        True          8   JIMMY CARTER              NaN
# 1                        True          8   JIMMY CARTER              NaN
# 2                        True          8   JIMMY CARTER              NaN
# 3                        True          8   JIMMY CARTER              NaN
# 4                        True          8   JIMMY CARTER              NaN
# ...                       ...        ...            ...              ...
# 1222                     True          7  JOE BIDEN[53]    JOE BIDEN[53]
# 1223                     True          7  JOE BIDEN[53]    JOE BIDEN[53]
# 1224                     True          7  JOE BIDEN[53]    JOE BIDEN[53]
# 1225                     True          7  JOE BIDEN[53]    JOE BIDEN[53]
# 1226                     True          7  JOE BIDEN[53]    JOE BIDEN[53]
#
# [1227 rows x 26 columns]

# %%
df_combination_drop = df_combination.drop("Election", axis=1)
df_combination_drop
# Out:
#       year          state            candidate  candidatevotes  totalvotes  \
# 0     1976        ALABAMA        CARTER, JIMMY          659170     1182850
# 1     1976        ALABAMA         FORD, GERALD          504070     1182850
# 2     1976         ALASKA         FORD, GERALD           71555      123574
# 3     1976         ALASKA        CARTER, JIMMY           44058      123574
# 4     1976        ARIZONA         FORD, GERALD          418642      742719
# ...    ...            ...                  ...             ...         ...
# 1222  2020  WEST VIRGINIA     TRUMP, DONALD J.          545382      794652
# 1223  2020      WISCONSIN  BIDEN, JOSEPH R. JR         1630866     3298041
# 1224  2020      WISCONSIN     TRUMP, DONALD J.         1610184     3298041
# 1225  2020        WYOMING  BIDEN, JOSEPH R. JR           73491      278503
# 1226  2020        WYOMING     TRUMP, DONALD J.          193559      278503
#
#      party_simplified  vote_percentage    Incumbent party nominee  \
# 0            DEMOCRAT        55.727269   GERALD FORD (REPUBLICAN)
# 1          REPUBLICAN        42.614871   GERALD FORD (REPUBLICAN)
# 2          REPUBLICAN        57.904575   GERALD FORD (REPUBLICAN)
# 3            DEMOCRAT        35.653131   GERALD FORD (REPUBLICAN)
# 4          REPUBLICAN        56.366136   GERALD FORD (REPUBLICAN)
# ...               ...              ...                        ...
# 1222       REPUBLICAN        68.631552  DONALD TRUMP (REPUBLICAN)
# 1223         DEMOCRAT        49.449537  DONALD TRUMP (REPUBLICAN)
# 1224       REPUBLICAN        48.822437  DONALD TRUMP (REPUBLICAN)
# 1225         DEMOCRAT        26.387867  DONALD TRUMP (REPUBLICAN)
# 1226       REPUBLICAN        69.499790  DONALD TRUMP (REPUBLICAN)
#
#        Challenger party nominee Party mandate  ... Major policy change  \
# 0     JIMMY CARTER (DEMOCRATIC)         False  ...               False
# 1     JIMMY CARTER (DEMOCRATIC)         False  ...               False
# 2     JIMMY CARTER (DEMOCRATIC)         False  ...               False
# 3     JIMMY CARTER (DEMOCRATIC)         False  ...               False
# 4     JIMMY CARTER (DEMOCRATIC)         False  ...               False
# ...                         ...           ...  ...                 ...
# 1222     JOE BIDEN (DEMOCRATIC)         False  ...            True[dr]
# 1223     JOE BIDEN (DEMOCRATIC)         False  ...            True[dr]
# 1224     JOE BIDEN (DEMOCRATIC)         False  ...            True[dr]
# 1225     JOE BIDEN (DEMOCRATIC)         False  ...            True[dr]
# 1226     JOE BIDEN (DEMOCRATIC)         False  ...            True[dr]
#
#       No social unrest No scandal No foreign or military failure  \
# 0                 True  False[cn]                      False[co]
# 1                 True  False[cn]                      False[co]
# 2                 True  False[cn]                      False[co]
# 3                 True  False[cn]                      False[co]
# 4                 True  False[cn]                      False[co]
# ...                ...        ...                            ...
# 1222         False[ds]  False[dt]                           True
# 1223         False[ds]  False[dt]                           True
# 1224         False[ds]  False[dt]                           True
# 1225         False[ds]  False[dt]                           True
# 1226         False[ds]  False[dt]                           True
#
#       Major foreign or military success Charismatic incumbent  \
# 0                                 False                 False
# 1                                 False                 False
# 2                                 False                 False
# 3                                 False                 False
# 4                                 False                 False
# ...                                 ...                   ...
# 1222                              False                 False
# 1223                              False                 False
# 1224                              False                 False
# 1225                              False                 False
# 1226                              False                 False
#
#      Uncharismatic challenger False keys  Actual winner Predicted winner
# 0                        True          8   JIMMY CARTER              NaN
# 1                        True          8   JIMMY CARTER              NaN
# 2                        True          8   JIMMY CARTER              NaN
# 3                        True          8   JIMMY CARTER              NaN
# 4                        True          8   JIMMY CARTER              NaN
# ...                       ...        ...            ...              ...
# 1222                     True          7  JOE BIDEN[53]    JOE BIDEN[53]
# 1223                     True          7  JOE BIDEN[53]    JOE BIDEN[53]
# 1224                     True          7  JOE BIDEN[53]    JOE BIDEN[53]
# 1225                     True          7  JOE BIDEN[53]    JOE BIDEN[53]
# 1226                     True          7  JOE BIDEN[53]    JOE BIDEN[53]
#
# [1227 rows x 25 columns]

# %%
df_combination_drop.columns
# Out:
# Index(['year', 'state', 'candidate', 'candidatevotes', 'totalvotes',
#        'party_simplified', 'vote_percentage', 'Incumbent party nominee',
#        'Challenger party nominee', 'Party mandate', 'No primary contest',
#        'Incumbent seeking re-election', 'No third party',
#        'Strong short-term economy', 'Strong long-term economy',
#        'Major policy change', 'No social unrest', 'No scandal',
#        'No foreign or military failure', 'Major foreign or military success',
#        'Charismatic incumbent', 'Uncharismatic challenger', 'False keys',
#        'Actual winner', 'Predicted winner'],
#       dtype='object')
